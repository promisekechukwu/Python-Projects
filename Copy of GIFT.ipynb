# %% [markdown]
# **Drug** **Inventory** **Management** **System**

# %% [markdown]
# **Task** **1**

# %%
#Variables
Drug_name="Paracetamol"
Price=850
Quantity_in_stock=250
Quantity_sold_today=65
Minimum_stock=100
Expired=False

# %% [markdown]
# **Task** **2**: Remaining stock

# %%
Quantity_in_stock=250
Quantity_sold_today=65

Remaining_stock=Quantity_in_stock-Quantity_sold_today
print(Remaining_stock)
# Out:
# 185

# %% [markdown]
# **Task** **3**:Sales Revenue

# %%
Price=850
Quantity_sold_today=65
Revenue=Price*Quantity_sold_today
print(Revenue)
# Out:
# 55250

# %% [markdown]
# **Task** **4**:Inventory Update

# %%
Quantity_in_stock=250
Quantity_sold_today=65
Quantity_in_stock-=Quantity_sold_today
print("Stock update:",Quantity_in_stock)
# Out:
# Stock update: 185

# %% [markdown]
# **Task** **5**:Restocking Check

# %%
Remaining_stock=185
Minimum_stock=100
Pharmacy_reorder=Remaining_stock<Minimum_stock
print("Needs Reorder:",Pharmacy_reorder)
# Out:
# Needs Reorder: False

# %% [markdown]
# **Task** **6**:Expiry Check

# %%
#Drug is not expired
Expired = False
Drug_is_safe = not Expired
print("Safe to sell:", Drug_is_safe)
# Out:
# Safe to sell: True

# %% [markdown]
# **Task** **7**: Final Approval

# %%
Continue_selling=(Remaining_stock>Minimum_stock)and (Drug_is_safe)
print("Continue_selling:",Continue_selling)
# Out:
# Continue_selling: True

# %% [markdown]
# **Task** **8**:Discount Eligibility

# %%
Condition1=Quantity_in_stock>200
Condition2=Revenue>50000
Discount_eligibilty=(Condition1)or(Condition2)
print("Discount_eligibility :",Discount_eligibilty)
# Out:
# Discount_eligibility : True

# %% [markdown]
# **Task** **9**:Inventory Summary

# %%
Drug_name="Paracetamol"
print("==================================")
print("DRUG INVENTORY REPORT ")
print("==================================")
print("Drug Name:",Drug_name)
print("Price per unit:#"+str(Price))
print("Current Stock:",Remaining_stock,"units")
print("Today's Sales:",Quantity_sold_today,"units")
print("Today's Revenue:#"+str(Revenue ))
print("Needs Restocking:",Pharmacy_reorder)
print("Expired:",Expired)
print("Safe to sell:",Continue_selling)
print("Eligible for Discount :",Discount_eligibilty)
print("====================================")
# Out:
# ...
# DRUG INVENTORY REPORT
# ...
# Drug Name: Paracetamol
# Price per unit:#850
# Current Stock: 185 units
# Today's Sales: 65 units
# Today's Revenue:#55250
# Needs Restocking: False
# Expired: False
# Safe to sell: True
# Eligible for Discount : True
# ...

# %% [markdown]
# BONUS CHALLENGE

# %%
#Variables
Drug_name="Amoxicillin"
Price=#1500
Quantity_in_stock=90
Quantity_sold_today=35
Minimum_stock=80
Expired=True

# %%
# Task 2: Remaining stock
Remaining_stock = Quantity_in_stock - Quantity_sold_today

print("Remaining_stock:", Remaining_stock)
# Out:
# Remaining_stock: 55

# %%
# Task 3: Sales Revenue
Revenue = Price * Quantity_sold_today

print("Revenue:", Revenue)
# Out:
# Revenue: 52500

# %%
# Task 4: Inventory Update
Quantity_in_stock-=Quantity_sold_today
print("Stock update:",Quantity_in_stock)
# Out:
# Stock update: 55

# %%
# Task 5: Restocking Check
Pharmacy_reorder = Remaining_stock < Minimum_stock
print("Needs Reorder:", Pharmacy_reorder)
# Out:
# Needs Reorder: True

# %%
# Task 6: Expiry Check
Drug_is_safe = not Expired
print("Safe to sell:", Drug_is_safe)
# Out:
# Safe to sell: False

# %%
# Task 7: Final Approval (Continue Selling)
Continue_selling = (Remaining_stock > Minimum_stock) and (Drug_is_safe)
print("Continue_selling:", Continue_selling)
# Out:
# Continue_selling: False

# %%
# Task 8: Discount Eligibility
Condition1 = Quantity_in_stock > 200
Condition2 = Revenue > 50000
Discount_eligibilty = (Condition1) or (Condition2)
print("Discount_eligibility :", Discount_eligibilty)
# Out:
# Discount_eligibility : True

# %%
# Task 9: Inventory Summary
print("==================================")
print("DRUG INVENTORY REPORT ")
print("==================================")
print("Drug Name:", Drug_name)
print("Price per unit: #" + str(Price))
print("Current Stock:", Remaining_stock, "units")
print("Today's Sales:", Quantity_sold_today, "units")
print("Today's Revenue: #" + str(Revenue))
print("Needs Restocking:", Pharmacy_reorder)
print("Expired:", Expired)
print("Safe to sell:", Continue_selling)
print("Eligible for Discount :", Discount_eligibilty)
print("====================================")
# Out:
# ...
# DRUG INVENTORY REPORT
# ...
# Drug Name: Amoxicillin
# Price per unit: #1500
# Current Stock: 55 units
# Today's Sales: 35 units
# Today's Revenue: #52500
# Needs Restocking: True
# Expired: True
# Safe to sell: False
# Eligible for Discount : True
# ...

# %% [markdown]
# Drug Comparison

# %%
print("\nComparison")

# Accessing data from the dictionaries
print("Paracetamol Revenue :", paracetamol_data['revenue'])
print("Amoxicillin Revenue :", amoxicillin_data['revenue'])

print("Paracetamol Needs Reordering:", paracetamol_data['needs_restocking'])
print("Amoxicillin Needs Reordering:", amoxicillin_data['needs_restocking'])

print("Paracetamol Safe to Sell:", paracetamol_data['safe_to_sell'])
print("Amoxicilllin Safe to Sell:", amoxicillin_data['safe_to_sell'])
# Out:
# Comparison
# Paracetamol Revenue : 55250
# Amoxicillin Revenue : 52500
# Paracetamol Needs Reordering: False
# Amoxicillin Needs Reordering: True
# Paracetamol Safe to Sell: True
# Amoxicilllin Safe to Sell: False

# %% [markdown]
# Conclusion
#
#
# 1.   Paracetamol made more revenue
# 2.   Amoxicillin needs to be restocked
# 3.  Amoxicillin should not be sold because the drug is expired
